# %% [markdown]
# # Transfer Learning with Linear Probe
#
#
# ## Basics
# In transfer learning, we use a model pre-trained on some large dataset. This is useful when our target dataset is small. This is common in fine-grained classification tasks (e.g. some specialized domain). Here, we will look at classifying dog species, which is a somewhat specialized task.
#
# We focus on linear probing, where we only learn weights for a single linear layer (head) over some feature extractor backbone. In terms of the backbone, we will use a pre-trained model from a recent popular neural network architecture family, Vision Transformers (ViT). We select one of the smaller variants, ViT-tiny, for compute efficiency.

# %%
import torch
import torchvision

! pip install timm==0.6.7
import timm
# Out:
# Collecting timm==0.6.7
#   Downloading timm-0.6.7-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: torch>=1.4 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from timm==0.6.7) (2.3.1)
# Requirement already satisfied: torchvision in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from timm==0.6.7) (0.18.1)
# Requirement already satisfied: filelock in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (4.12.2)
# Requirement already satisfied: sympy in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (1.12.1)
# Requirement already satisfied: networkx in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (3.2.1)
# Requirement already satisfied: jinja2 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (3.1.4)
# Requirement already satisfied: fsspec in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torch>=1.4->timm==0.6.7) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4->timm==0.6.7) (12.3.101)
# Requirement already satisfied: numpy in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torchvision->timm==0.6.7) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from torchvision->timm==0.6.7) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from jinja2->torch>=1.4->timm==0.6.7) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /home/pankaja/anaconda3/envs/tf-dev/lib/python3.9/site-packages (from sympy->torch>=1.4->timm==0.6.7) (1.3.0)
# Downloading timm-0.6.7-py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.0/510.0 kB 119.2 kB/s eta 0:00:0000:0100:01
# Installing collected packages: timm
# Successfully installed timm-0.6.7

# %%
! mkdir datasets
! ls
# Out:
#  cifar_net.pth	 Part-1-Pytorch_Training_Pipeline.ipynb
#  data		 Part-2-Transfer-Learning.ipynb
#  datasets	'Week 2.pdf'

# %%
# download the data

ds_train = torchvision.datasets.OxfordIIITPet(root="datasets", split="trainval", download=True)
ds_val = torchvision.datasets.OxfordIIITPet(root="datasets", split="test", download=True)
# Out:
# Downloading https://thor.robots.ox.ac.uk/pets/images.tar.gz to datasets/oxford-iiit-pet/images.tar.gz
# 100.0%
# Extracting datasets/oxford-iiit-pet/images.tar.gz to datasets/oxford-iiit-pet
# Downloading https://thor.robots.ox.ac.uk/pets/annotations.tar.gz to datasets/oxford-iiit-pet/annotations.tar.gz
# 100.0%
# Extracting datasets/oxford-iiit-pet/annotations.tar.gz to datasets/oxford-iiit-pet

# %%
# let's first look at the data
from matplotlib import pyplot as plt
import numpy as np

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(ds_train), size=(1,)).item()
    img, label = ds_train[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(ds_train.classes[label])
    plt.axis("off")
    plt.imshow(np.array(img))
plt.show()

# %% [markdown]
# ## CNNs, ViTs
#
# Networks we use for image processing - they are both SOTA in various use cases!

# %%
# download pre-trained model
# using vit tiny model
model = timm.models.vit_tiny_patch16_224(pretrained=True)

# %%
model
# Out:
# VisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 192, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (blocks): Sequential(
#     (0): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (8): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (9): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (10): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (11): Block(
#       (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=192, out_features=576, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=192, out_features=192, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=192, out_features=768, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=768, out_features=192, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#   (fc_norm): Identity()
#   (head): Linear(in_features=192, out_features=1000, bias=True)
# )

# %%
# output feature size of model
model.head.in_features
# Out:
# 192

# %%
# classes in dataset
num_classes = len(ds_train.classes)
num_classes
# Out:
# 37

# %% [markdown]
# The linear layer we learn over the ViT backbone should project features from 192-space to 37-space using a learnable weight matrix. We implement this as a PyTorch Linar Layer (which handled all learning components internally).

# %%
model.head.weight.T.shape
# Out:
# torch.Size([192, 1000])

# %%
# freeze backbone (we don't want to update backbone parameteres)
for param in model.parameters():
  param.requires_grad = False

# change linear head & set it to learn weights
model.head = torch.nn.Linear(in_features=model.head.in_features, out_features=num_classes)
for param in model.head.parameters():
  param.requires_grad = True

# %%
# let's create a dataloader - this converts raw images to fixed shaped matrices of data-type Tensor (that can store gradients).
# we also normalize out images - normalization of input is usually very important!

from torch.utils.data import DataLoader
from torchvision import transforms


train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

ds_train = torchvision.datasets.OxfordIIITPet(root="datasets", split="trainval", download=True, transform=train_transform)
ds_val = torchvision.datasets.OxfordIIITPet(root="datasets", split="test", download=True, transform=test_transform)

train_dataloader = DataLoader(ds_train, batch_size=64, shuffle=True)
test_dataloader = DataLoader(ds_val, batch_size=64, shuffle=False)

# %%
# move model to GPU
model = model.cuda()

# loss function
loss_fn = torch.nn.CrossEntropyLoss()

# optimizer - SGD: stochastic gradient descent
lr = 1e-3
# Adam / AdamW - decoupled optimization (computation efficient) / LAMB (good large scale distributed training)
optim = torch.optim.AdamW(params=model.head.parameters(), lr=lr)

# Cyclic Learning Rates
# Reduce the learning rate

# %%
# train and test functions

def train_one_epoch(dataloader, model, loss_fn, optimizer, device="cpu", verbose=False):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if verbose and batch % 10 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:.3f}  [{current:>5d}/{size:>5d}]")

    return loss


def test_acc(dataloader, model, loss_fn, device="cpu", verbose=False):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0
    print(f"Running evaluation on {size} samples.")
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    if verbose:
      print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return test_loss, correct

# %%
train_loss = train_one_epoch(train_dataloader, model, loss_fn, optim, device="cuda", verbose=True)
print(f"Train loss after 1 epoch: {train_loss:.2f}")
# Out:
# loss: 5.797  [    0/ 3680]
# loss: 4.472  [  640/ 3680]
# loss: 3.427  [ 1280/ 3680]
# loss: 2.585  [ 1920/ 3680]
# loss: 1.948  [ 2560/ 3680]
# loss: 2.089  [ 3200/ 3680]
# Train loss after 1 epoch: 1.76

# %%
test_loss, acc = test_acc(test_dataloader, model, loss_fn, device="cuda", verbose=True)
# Out:
# Running evaluation on 3669 samples.
# Test Error:
#  Accuracy: 48.8%, Avg loss: 1.780297

# %% [markdown]
# We will train for 10 epochs to see how well the model gets. We can train for much longers to get better performance (left to students to try on their own).

# %%
for epoch in range(10):
  train_loss = train_one_epoch(train_dataloader, model, loss_fn, optim, device="cuda", verbose=False)
  test_loss, acc = test_acc(test_dataloader, model, loss_fn, device="cuda", verbose=False)
  print(f"Train Loss @ {epoch} epochs: {train_loss:.3f}")
  print(f"Test Loss / Acc @ {epoch} epochs: {test_loss:.3f} / {(100*acc):.1f}")
# Out:
# Running evaluation on 3669 samples.
# Train Loss @ 0 epochs: 1.702
# Test Loss / Acc @ 0 epochs: 1.280 / 62.2
# Running evaluation on 3669 samples.
# Train Loss @ 1 epochs: 0.734
# Test Loss / Acc @ 1 epochs: 1.149 / 65.7
# Running evaluation on 3669 samples.
# Train Loss @ 2 epochs: 0.853
# Test Loss / Acc @ 2 epochs: 1.062 / 68.4
# Running evaluation on 3669 samples.
# Train Loss @ 3 epochs: 0.625
# Test Loss / Acc @ 3 epochs: 1.004 / 69.5
# Running evaluation on 3669 samples.
# Train Loss @ 4 epochs: 1.295
# Test Loss / Acc @ 4 epochs: 0.964 / 70.9
# Running evaluation on 3669 samples.
# Train Loss @ 5 epochs: 0.436
# Test Loss / Acc @ 5 epochs: 0.934 / 72.1
# Running evaluation on 3669 samples.
# Train Loss @ 6 epochs: 1.151
# Test Loss / Acc @ 6 epochs: 0.936 / 71.8
# Running evaluation on 3669 samples.
# Train Loss @ 7 epochs: 0.756
# Test Loss / Acc @ 7 epochs: 0.918 / 72.5
# Running evaluation on 3669 samples.
# Train Loss @ 8 epochs: 0.814
# Test Loss / Acc @ 8 epochs: 0.915 / 72.3
# Running evaluation on 3669 samples.
# Train Loss @ 9 epochs: 1.017
# Test Loss / Acc @ 9 epochs: 0.886 / 73.0
