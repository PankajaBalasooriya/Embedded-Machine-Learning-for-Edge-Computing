# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import re
import time

# %%
# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
#

# %%
torch.manual_seed(1337)

# %%
# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
# Split the text into words                    
words = re.findall(r'\S+|\n|\n\n', text)                    

# Create vocabulary
vocab = sorted(set(words))
vocab_size = len(vocab)

# Create mappings
stoi = {word: i for i, word in enumerate(vocab)}
itos = {i: word for i, word in enumerate(vocab)}

# Update encode and decode functions
encode = lambda s: [stoi[word] for word in re.findall(r'\S+|\n|\n\n', s)]
decode = lambda l: ' '.join([itos[i] for i in l])


print(f'Some words in vocabulary: {vocab[10000:20000]}')
print(f'vocab_size: {vocab_size}')
# Out:
# Some words in vocabulary: ['dull;', 'dullest', 'dulness,', 'duly', 'dumb', 'dumb,', 'dumbly', 'dumbness,', 'dump', 'dump,', 'dumps', 'dumps?', "dun's", 'dun,', 'dungeon.', 'dungy', 'durance,', 'durance?', 'durst', 'dusky', 'dust', 'dust,', 'dust.', 'dust?', 'duteous', 'duties,', 'duty', 'duty!', "duty's", 'duty,', 'duty.', 'duty:', 'duty;', 'duty?', 'dwell', 'dwellest', 'dwelling', 'dwelling,', 'dwells', 'dwells,--which', 'dwells;', 'dyed', 'dying', 'dying,', "e'en", "e'er", 'each', 'each,', 'eager', 'eagle', "eagle's", "eagle's,", 'eagle,', 'eagle-winged', 'eagles', 'eagles.', 'ean:', 'ear', 'ear,', 'ear-deafening', 'ear.', 'ear:', 'ear;', 'earl', 'earl.', 'earldom', 'earldom,--', 'earliness', 'earls', 'earls,', 'early', 'early:', 'early?', 'earn', "earn'd", 'earned', 'earnest', 'earnest,', 'earnest.', 'earnest:', 'earnest?', 'earnestly', 'earnestness', 'ears', 'ears!', 'ears,', 'ears--waving', 'ears.', 'ears:', 'ears;', 'ears?', 'earth', 'earth!', "earth's", 'earth,', 'earth.', 'earth:', 'earth;', 'earth?', 'earthen', 'earthly', 'earthly,', 'earthquake', 'earthy', 'ease', 'ease,', 'ease.', "ease.'", "ease:'", "ease?'", 'eased', 'eased,', 'easeful', 'easier', 'easiest', 'easily', 'east', 'east,', 'east.', 'east:', 'eastern', 'easy', 'easy-melting', 'easy.', 'easy:', 'eat', 'eat!', 'eat,', 'eat.', 'eat;', 'eaten', 'eaten:', 'eating', 'eating.', 'eats', 'eaves-dropper,', 'ebb', "ebb'd,", 'ebb,', 'ebb.', 'echo:', 'echoes', 'eclipsed.', 'edge', 'edge,', 'edge.', 'edge;', 'edges', 'edict', 'edicts', 'edifices', 'education', 'eel,', 'effect', 'effect,', 'effect.', 'effect:', 'effect;', 'effected', 'effects', 'effects,', 'effectual,', 'effeminate', 'effuse', 'effusion', 'egally', 'egg', 'egg,', 'eggs', 'eggs;', 'eight', 'eight-year-old', 'eight.', 'eighteen', 'either', "either's", 'either,', 'either.', 'eject', 'elbow,', 'elbow.', 'eld;', 'elder', 'elder,', 'elder:', 'elder;', 'elders,', 'elders.', 'eldest', 'elected', 'election', 'election.', 'election;', 'elements', 'elements,', 'elevated', 'eleven', 'elflocks', 'ell', 'eloquence,', 'eloquence.', 'eloquence:', 'eloquent', 'else', 'else,', 'else.', 'else:', 'else;', 'else?', 'elsewhere', 'elsewhere.', "elvish-mark'd,", "embark'd", 'embassade,', 'embassage', 'embassies', 'embassies;', "emboss'd;", "embowell'd", 'embrace', 'embrace!', 'embrace,', 'embrace:', 'embraced', 'embraced,', 'embraced:', 'embracement.', 'embracements', 'embracements,', 'embraces', 'embraces,', 'embracing,', "embroider'd", 'eminent', 'emmence', 'emmew', 'emperor.', 'empery,', 'empire', 'empiricutic,', 'employ', "employ'd", "employ'd,", "employ'd.", 'employment:', 'employments,', "empoison'd,", 'emptier', 'empties', 'empty', 'empty,', 'empty;', 'empty?', 'emulation', 'emulation.', 'enacts', "enamour'd", 'encamp', "encamp'd,", 'encertainties', 'enchantment.--', 'enclosed', 'encloseth', "encompass'd", 'encompasseth', 'encounter', "encounter'd", 'encounter,', 'encounter.', 'encountering,', 'encounters', 'encounters,', 'encourage', 'encouragement', 'encouragement.', 'end', 'end,', 'end.', 'end:', 'end;', 'endart', 'endeavour:', 'endeavours', 'ended', 'ended,', 'ending', 'endless', 'endow', "endow'd", 'endowments', 'ends', 'ends,', 'ends.', 'endure', 'endured', 'endured!', 'endured.', 'endured:', 'endures', 'enduring.', 'enemies', 'enemies!', "enemies'", 'enemies,', 'enemies.', 'enemies:', 'enemies;', 'enemies?', 'enemy', "enemy's", 'enemy,', 'enemy.', 'enemy:', 'enemy:--', 'enemy;', 'enemy?', 'enfoldings?', 'enforce', 'enforced', 'enforcement', 'enfranchise', 'enfranchised,', 'enfranchisement,', 'engaged', "engaol'd", 'engenders', 'engine,', 'engrave', 'engross', "engross'd,", 'engrossing', 'enigma?', 'enjoin', "enjoin'd", 'enjoy', "enjoy'd", "enjoy'd,", "enjoy'd:", 'enjoy,', 'enjoy.', 'enjoy;', 'enjoying', 'enjoys', 'enjoys,', 'enlargement', 'enmity', 'enmity!', "enmity's", 'enmity,', 'enmity.', 'enmity:', 'enmity;', 'ennoble', 'enointed:', 'enormity', 'enough', 'enough!', 'enough,', "enough,'twill", 'enough.', 'e ...
# vocab_size: 25671

# %%
# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %%
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        perplexities = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
            perplexities[k] = torch.exp(loss).item()
        # out[split] = losses.mean()
        out[split + '_loss'] = losses.mean()
        out[split + '_perplexity'] = perplexities.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

# %%
model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')
# Out:
# 3.512903 M parameters

# %%
# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

start_time = time.time()
for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train_loss']:.4f}, val loss {losses['val_loss']:.4f}, train perplexity {losses['train_perplexity']:.4f}, val perplexity {losses['val_perplexity']:.4f}")


    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

end_time = time.time()
# Out:
# step 0: train loss 10.3086, val loss 10.3013, train perplexity 30000.1250, val perplexity 29781.6406
# step 100: train loss 6.9402, val loss 7.0667, train perplexity 1044.9220, val perplexity 1184.2147
# step 200: train loss 6.6928, val loss 6.9017, train perplexity 814.9506, val perplexity 1002.2777
# step 300: train loss 6.5316, val loss 6.8018, train perplexity 694.4224, val perplexity 908.8984
# step 400: train loss 6.4174, val loss 6.7254, train perplexity 618.8960, val perplexity 843.5651
# step 500: train loss 6.2655, val loss 6.6543, train perplexity 533.7296, val perplexity 787.3753
# step 600: train loss 6.2049, val loss 6.6443, train perplexity 502.4941, val perplexity 781.0638
# step 700: train loss 6.0987, val loss 6.5770, train perplexity 451.7906, val perplexity 730.1487
# step 800: train loss 5.9802, val loss 6.5516, train perplexity 401.6569, val perplexity 712.3526
# step 900: train loss 5.9196, val loss 6.5236, train perplexity 377.5457, val perplexity 692.5779
# step 1000: train loss 5.8600, val loss 6.5102, train perplexity 355.9966, val perplexity 683.9400
# step 1100: train loss 5.7657, val loss 6.4623, train perplexity 323.6112, val perplexity 654.3525
# step 1200: train loss 5.6623, val loss 6.4457, train perplexity 292.0497, val perplexity 643.8928
# step 1300: train loss 5.6126, val loss 6.4447, train perplexity 278.2122, val perplexity 643.9975
# step 1400: train loss 5.5639, val loss 6.4151, train perplexity 265.8701, val perplexity 621.9068
# step 1500: train loss 5.5082, val loss 6.4011, train perplexity 250.6351, val perplexity 615.9147
# step 1600: train loss 5.4364, val loss 6.4211, train perplexity 233.4932, val perplexity 629.6140
# step 1700: train loss 5.3686, val loss 6.4495, train perplexity 218.5915, val perplexity 647.2703
# step 1800: train loss 5.3455, val loss 6.3858, train perplexity 212.9751, val perplexity 607.3964
# step 1900: train loss 5.2689, val loss 6.4353, train perplexity 197.4771, val perplexity 641.8900
# step 2000: train loss 5.2458, val loss 6.4418, train perplexity 192.9700, val perplexity 644.1213
# step 2100: train loss 5.2102, val loss 6.5072, train perplexity 185.9093, val perplexity 689.7146
# step 2200: train loss 5.1412, val loss 6.5096, train perplexity 173.5943, val perplexity 689.6063
# step 2300: train loss 5.0875, val loss 6.4883, train perplexity 164.4516, val perplexity 674.7853
# step 2400: train loss 5.0635, val loss 6.5173, train perplexity 160.4389, val perplexity 698.3832
# step 2500: train loss 5.0084, val loss 6.5291, train perplexity 151.7150, val perplexity 704.1481
# step 2600: train loss 4.9675, val loss 6.5166, train perplexity 145.7615, val perplexity 696.7472
# step 2700: train loss 4.9187, val loss 6.6030, train perplexity 138.8272, val perplexity 763.3244
# step 2800: train loss 4.8812, val loss 6.5580, train perplexity 133.4637, val perplexity 724.8561
# step 2900: train loss 4.8586, val loss 6.5786, train perplexity 130.7850, val perplexity 748.4847
# step 3000: train loss 4.7960, val loss 6.6659, train perplexity 122.6707, val perplexity 811.9498
# step 3100: train loss 4.7758, val loss 6.6197, train perplexity 120.3125, val perplexity 772.4842
# step 3200: train loss 4.7261, val loss 6.6518, train perplexity 114.2234, val perplexity 803.2228
# step 3300: train loss 4.6963, val loss 6.6869, train perplexity 110.9960, val perplexity 833.7841
# step 3400: train loss 4.6642, val loss 6.7228, train perplexity 107.5589, val perplexity 866.3061
# step 3500: train loss 4.6564, val loss 6.7512, train perplexity 106.3890, val perplexity 888.1871
# step 3600: train loss 4.6095, val loss 6.8081, train perplexity 101.5732, val perplexity 944.2288
# step 3700: train loss 4.5710, val loss 6.7917, train perplexity 97.7575, val perplexity 923.7340
# step 3800: train loss 4.5387, val loss 6.8012, train perplexity 94.9773, val perplexity 936.2696
# step 3900: train loss 4.5073, val loss 6.8133, train perplexity 91.7967, val perplexity 950.0503
# step 4000: train loss 4.4753, val loss 6.8720, train perplexity 88.8769, val perplexity 1002.6117
# step 4100: train loss 4.4236, val loss 6.8806, train perplexity 84.5189, val perplexity 1014.3734
# step 4200: train loss 4.4132, val loss 6.8699, train perplexity 83.5637, val perplexity 998.1603
# step 4300: train loss 4.3701, val loss 6.8880, train perplexity 80.0501, val perplexity 1023.2817
# step 4400: train loss 4.3405, val loss 6.9449, train perplexity 77.6443, val perplexity 1089.0173
# step 4500: train loss 4.3110, val loss 6.9316, train perplexity 75.3530, val perplexity 1067.6067
# step 4600: train loss 4.3051, val loss 6.9427, train perplexity 74.8794, val perplexity 1080.3832
# step 4700: train loss 4.2526, val loss 6.9681, train perplexity 71.0423, val perplexity 1103.4215
# step 4800: train loss 4.2209, val loss 6.9777, train perplexity 68.9057, val perplexity 1121.6302
# step 4900: train loss 4.2043, val loss 7.0085, train perplexity 67.6920, val perplexity 1165.9882
# step 4999: train loss 4.1600, val loss 7.0733, train perplexity 64.6438, val perplexity 1241.8163

# %%
training_time = end_time - start_time

# %%
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
#  ESCALUS:
#  Stand you go; ten thousand counsel?
#
#  POMPEY:
#  Nay, sir; I might not say 'ay' with a
#  crooked and hanged after. if I prove cracking
#
#  BUCKINGHAM:
#  No more,
#
#  GLOUCESTER:
#  Here in your tongue,
#
#  GLOUCESTER:
#  Lest for my heart! go, if you warp.
#
#  QUEEN ELIZABETH:
#  Not the course of them.
#
#  YORK:
#  On York Should thy falsehood learn.
#
#  DUCHESS:
#  We know the injuries
#
#  Page:
#  Then you have deceived; is not well to-morrow,
#
#  MENENIUS:
#  And so I could be a prince
#  Such a penny. livery in my life-time
#
#  VOLUMNIA:
#  Well, figuring full of this: and bring
#  The evil looking of us have done,
#  If any of your my head; be turn'd, than one, this
#  Where will not service before no more.
#
#  JOHN OF GAUNT:
#  No hand to be, 'tis untimely cropp'd!
#  Perfume for, after the dearth is bring
#  And so we look in our guiltless Edward, cannot offend thee,
#  Unless I slain to sue good wholesome it;
#  I must take the duty of it still your state
#  That staggers Commit you shall return at a dream;
#  For Margaret have I myself had rather as this:
#  Lest shame a grey that they remember, with envy; cold rumours.
#  That may hell be more unconstant.
#
#  SLY:
#  'Twas we can; below up the way that you now his minority
#  Did you dined in a grave of great world ransomed,
#  I'll have mistress nor any again to bones.
#  Give me in Rome, else, or all allegiance the clouds,
#
#  JOHN OF GAUNT:
#  Which please the duke and revolts, to his folly,
#  Is thy stainless my body's again:
#  And kneel to live their strength, if Warwick were he so sad?
#  Simple, than mine honour, DUKE VINCENTIO:
#  Else may betide.
#
#  ELBOW:
#  Romeo! I have: prepare yourself.
#
#  CLAUDIO:
#  Do, Paulina;
#  Thou mayst it not show
#  Edward by one that can understand with the gentlewoman
#  In that hath sounded me with distaffs. charge.
#
#  LEONTES:
#  Should some other hands again
#  Hold on the towns of our entrance:
#  Good Captain madam; these outrages. I were abed!
#  Or lie too: greater themes
#  My gracious possible hath, my love, and I do me it
#  Retire and so waked or any shall importune,
#  And interjoin those the extreme way: so bosom
#  Her vestal you'll cheer note of King Henry,
#  usurp'st by the while. But have you forget, to your
#  No vault which now stands, you buy the maid:
#  reflect navy we shed. Do you kings,
#  But, for but his are sirrah.
#
#  ISABELLA:
#  Come on, cry havoc, for the glasses of rubs,
#  they have we censured? for you.
#  For a man; I took the greater talk
#  Are you the reason of me, and prove false;
#  As ere chaste, in their tender father's death?
#
#  MONTAGUE:
#  Why that you would hence to him.
#
#  KING RICHARD III:
#  Your general is the chase: before my feet;
#  Whereof I know, no issue of the new head?
#
#  DORSET:
#  FRIAR PETER:
#  Now,
#
#  Wine, my lord; and York; give him disparagement:
#  Good Buckingham whiles York's lords, your royal hand;
#  Being yoke but would he ne'er hear themselves make a very
#  Whiles unfold.
#  Or reason for me.
#
#  LEONTES:
#  The way
#
#  CAMILLO:
#  Well, the Welshman cannot slew him a lady's know
#  Though the best time to have hewn the people,--
#  But now I have put the gossamer
#  As potent gods, for a warranted of your life.
#
#  LUCIO:
#  Nay, but Lewis
#
#  PRINCE EDWARD:
#  I spy him slaves to him, in some words:
#  For every prince, like a mercy: with Pembroke I attend
#  The bird that glory under the cloudy man,
#  Susan stately means, would they took the keeping bear alone
#  May with their loves, which bore the rascal of the lewd
#  Which, underneath most replenished profit were in the grave.
#
#  BENVOLIO:
#  No challenge tidings.
#  May we like my bonds farewell; myself in
#  Ay, and do not the earth!
#  He capers nimbly to mow
#  What fair there?
#
#  Servant:
#  Nay, I not kill it that you base-born be.
#
#  GLOUCESTER:
#  More you, sir; than her as the thing comes it the gods
#  That ever she shall know up the sun
#  Will be King Henry's Leontes and what amends
#  Be not bed, to the open blood who did despise
#  Hours, minutes? noon, midnight? his minim is
#  Against and Henry together and person.
#  Thine words, we make us eyes
#  With the westward the direst degree; Was crown'd who speaks
#  To plot, contrive,
#  If it in thy tongue not cross'd my throne?
#  chance an son general: and his queen
#  Have robb'd the soldiers in itself whose gratitude day,
#  The tiger take of you; and and Trust, her words,
#  To lie in the glittering court?
#  Our fens, before the EDWARD and Dion, authority,
#  The duke's ladies whereon not yet young
#  Shalt there? What say you?
#  You have seen some score what fair 'twas execution,
#  My lord's in the airy power and cloak:
#  Whilst to prove my part ceremony. come uncle my life gives
#  Persuade my Lord against thy head in his blood, and crown,
#  Elected his red queen.
#
#  AUTOLYCUS:
#  Warwick, to your bum law, till sir; I am his:
#  Which your brother as not my sons.
#
#  First ask come you read Coriolanus.
#
#  HERMIONE:
#  These fifteen spectators, be your queen, till not that your Three
#  But that honesty doing worthy claim you may;
#  Than this to give him with your where:
#  And with him up the rest; o' this point come Philip
#  Which joy and heir was it to the Christian;
#  When empty plant Richard of the table.
#  Please what says a woman to thine subjects,
#  That lift the death-darting affords. For our nine adversaries,
#  For you give you not gaze so unprovided?
#
#  PAULINA:
#  his.
#  It is no rest: I promised I swear in kings'
#  In the downfall of Hob and state had issued,
#  To him health!
#  Be in digestion a renown'd by and arms,
#  But I can set me shall go an enemy,
#  But by her at the thank If remember
#  Does 'Charge! us, the postern of the whip with his
#  disposition; and aptly destruction! But graciously more,
#  Think'st his happiness were newer to the state,
#  And had prophets the napkin, can I have heard me dead!
#  For, by his country I knew that, they will sigh
#  There is the merest weeds of Wiltshire is your Seely,
#  And warriors on his state, by the misty
#  The urging of his father's star
#  How they hull, expecting is set on all gaunt:
#  The curfew-bell is hence? in the table that crown, their
#  I know, hold you thy kindred and pace that I chide
#  To see! to the land for there do out-pray death:
#  His name hath been in the market-place;
#  Whilst with cursing home: and Nell. their backs,
#  pretty one; that he queen, than you heard him. If her say
#  Where please you, which would not a rose
#  But she knew marrow, work.
#
#  First Watchman:
#  Then weep he is the guilty shows odds freely granted:
#  Where I intended, not? shores 'twas means thy tongue
#  weather the heart wrapt that the name;
#  Dive, is he seen already mothers:
#  But courage them mules, cheer his neck,
#  That any creeping venom'd you the encounter of his rock,
#  Which industry being enthralled with the Volsces shunning unto the rites
#  Which you dead, daughter, you without imaginary.
#
#  LUCENTIO:
#  Give me you come to try him the crown?
#
#  MOPSA:
#  MARCIUS:
#  The wrong be all, down i' the good tears now?
#
#  Nurse:
#  Peace, charity, before us.
#
#  DUCHESS and good Petruchio, begin to it is at the Volsces
#  Cominius, for the faults of a face, methought,--I
#  Is my body's doomsday. Yes, I sleep the gentlewoman in quiet
#  To see you find me with me in, in his death?
#  For you have yielded and not make to cry my lords,
#  My malice reply to my hand, him; and hours: bush
#  Nothing what we are not honest, honourable:' and
#  Wherefore like your brother joints and pluck her coming not?
#  The bay-trees and offices of death.
#  His better husband. O my tongue back to my babe:
#
#  HASTINGS:
#  My lord, we shall make my brother my fair princess,
#  I'll bear my sweet circled I arm'd to think.
#
#  JOHN sweet money?
#  And doth some slander for what name embraced hath done.
#  For thy kinsman, mistress was a Capulet. What were not poor,
#  his knees: hath thy neck did pardon'd her.
#
#  Lord:
#  Marry, Come, hanging. Come, come, my lord, go
#  This shall bewray unto his throat: be furious, or friend,
#  You'll strike this fair rivers of all the world
#  And marry me with slow but surcease:
#  Prosperity this gracious uncle-- but dream.
#  Adding here, thou that thought slipp'd him Ere he swears,
#  The presentation of my wars to the watch.
#
#  DUCHESS:
#  Because I was a morn she warmth,
#  Came of a handsome, shall hinder life's noble pence
#  Obeying this young princes! ah, what he stares you parted
#  From our wonder: choler trudge and their chairs with Warwick.
#  Lord point. Then, no, in nothing traitors and that's content the
#  After in his highness of the one, of these--
#  Once more, near, Plantagenet, and that's hanged executed.
#
#  COMINIUS:
#  Though he without a horseman,
#
#  MENENIUS:
#  This afternoon,
#  Therefore aboard; that beauteous run the surly
#  To do the time o'erpast; Tranio, be avoided,
#  And when awake my lord is breeding and face.
#
#  JULIET:
#  So Phaethon was in a boat
#
#  LADY GREY:
#  Bear an Montague, and there's grief.
#
#  BISHOP OF CARLISLE:
#  No, well I am not a fellow in his son
#  beggarly a burthen for the wind a word.
#  O Exeter, that thou no man was born!
#
#  JOHN OF GAUNT:
#  Boy! but a God's name, for a boat
#
#  EDWARD:
#  I beseech you more wonders than a name by thine ear;
#  In person much enough to taste of on cold king!
#
#  JULIET:
#  That thou dost thou there, 'tis more than a chair
#  The helms my faith, of Clarence, and none guest
#  Were not this good deed on a month dead?
#
#  HENRY BOLINGBROKE:
#  'Tis any yet:
#
#  FRIAR PETER:
#  I not like me? O, find out it.
#  If I, in my life; all grace to bed.
#
#  First Murderer:
#  I cannot confess promise him pale, here both,
#  Have with them a party-verdict gave: envying out of change, as
#  comes, to steal ceremony. of his brother.
#
#  Second Senator:
#  My lord, you and thereto seemed

# %%
def generate_sample(model, seed_text, max_new_tokens=100):
    context = torch.tensor([encode(seed_text)], dtype=torch.long, device=device)
    return decode(model.generate(context, max_new_tokens=max_new_tokens)[0].tolist())

sample_text = generate_sample(model, "To be or not to be")

# %%
print("Training Time: {training_time}")
print(sample_text)
# Out:
# Training Time: {training_time}
# To be or not to be 'scaped
#  For the penury, by march'd to your minds,
#  No: he, like the idle rivers of you wot
#  So mercy betwixt with a king as friends. And she am
#  as young in manner as great run divine is homicide;
#  And mastership on his native progress,
#
#  First Murderer:
#  No, no; but by herself i' the tables and himself
#  when Romeo were a fault as heinous, absent petition;
#  Because 'tis too prenzie though she counts
#  Under on a mutiny of a torch-bearer,
#
#  RICHARD:
#  Wife, sin! morning. and willing
